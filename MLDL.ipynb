# %% [markdown]
# <a href="https://colab.research.google.com/github/invadoli/Projekti3_ML_DL/blob/main/MLDL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("balraj98/duts-saliency-detection-dataset")
# Out:
# Using Colab cache for faster access to the 'duts-saliency-detection-dataset' dataset.

# %%
import os
print(os.listdir(path))
# Out:
# ['DUTS-TE', 'metadata.csv', 'DUTS-TR']
